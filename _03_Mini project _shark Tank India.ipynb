# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_excel("D:\\EDA_Shark_Tank_India.xlsx")

# %%
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.head(15)
# Out:
#     episode_number  pitch_number           brand_name  \
# 0                1             1  BluePine Industries
# 1                1             2        Booz scooters
# 2                1             3  Heart up my Sleeves
# 3                2             4           Tagz Foods
# 4                2             5       Head and Heart
# 5                2             6         Agro tourism
# 6                3             7          Qzense Labs
# 7                3             8            Peeschute
# 8                3             9                 NOCD
# 9                4            10                Cosiq
# 10               4            11         JhaJi Achaar
# 11               4            12               Bummer
# 12               5            13          Revamp Moto
# 13               5            14         Hungry Heads
# 14               5            15   Shrawani Engineers
#
#                                              idea  deal  pitcher_ask_amount  \
# ...

# %%
df.tail(15)
# Out:
#      episode_number  pitch_number          brand_name  \
# 102              32           103        Thea and Sid
# 103              32           104     Experential Etc
# 104              32           105          GrowFitter
# 105              32           106            Med Tech
# 106              33           107       Colour Me Mad
# 107              33           108              Mavi's
# 108              33           109          Tweek Labs
# 109              33           110              Proxgy
# 110              34           111  Nomad Food Project
# 111              34           112         Twee in One
# 112              34           113       Green Protein
# 113              34           114             On2Cook
# 114              35           115       Jain Shikanji
# 115              35           116               Woloo
# 116              35           117        Elcare India
#
#                                           idea  deal  pitcher_ask_amount  \
# ...

# %%
df.columns
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
df.shape
# Out:
# (117, 28)

# %%
df.dtypes
# Out:
# episode_number             int64
# pitch_number               int64
# brand_name                object
# idea                      object
# deal                       int64
# pitcher_ask_amount       float64
# ask_equity               float64
# ask_valuation            float64
# deal_amount              float64
# deal_equity              float64
# deal_valuation           float64
# ashneer_present            int64
# anupam_present             int64
# aman_present               int64
# namita_present             int64
# vineeta_present            int64
# peyush_present             int64
# ghazal_present             int64
# ashneer_deal               int64
# anupam_deal                int64
# aman_deal                  int64
# namita_deal                int64
# vineeta_deal               int64
# peyush_deal                int64
# ghazal_deal                int64
# total_sharks_invested      int64
# amount_per_shark         float64
# equity_per_shark         float64
# dtype: object

# %%
df.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
df.describe().T
# Out:
#                        count         mean           std      min     25%  \
# episode_number         117.0    18.735043     10.070778  1.00000   10.00
# pitch_number           117.0    59.000000     33.919021  1.00000   30.00
# deal                   117.0     0.555556      0.499041  0.00000    0.00
# pitcher_ask_amount     117.0   319.854709   2767.842777  0.00101   45.00
# ask_equity             117.0     5.188034      3.892121  0.25000    2.50
# ask_valuation          117.0  3852.462479  11931.601957  0.01000  666.67
# deal_amount            117.0    31.982915     36.687391  0.00000    0.00
# deal_equity            117.0     8.963504     13.106769  0.00000    0.00
# deal_valuation         117.0   467.104872    919.988864  0.00000    0.00
# ashneer_present        117.0     0.837607      0.370397  0.00000    1.00
# anupam_present         117.0     1.000000      0.000000  1.00000    1.00
# aman_present           117.0     0.837607      0.370397  0.00000    1.00
# ...

# %%
df.isnull()
# Out:
#      episode_number  pitch_number  brand_name   idea   deal  \
# 0             False         False       False  False  False
# 1             False         False       False  False  False
# 2             False         False       False  False  False
# 3             False         False       False  False  False
# 4             False         False       False  False  False
# ..              ...           ...         ...    ...    ...
# 112           False         False       False  False  False
# 113           False         False       False  False  False
# 114           False         False       False  False  False
# 115           False         False       False  False  False
# 116           False         False       False  False  False
#
#      pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 0                 False       False          False        False        False
# 1                 False       False          False        False        False
# ...

# %%
df.isnull().sum()
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %%
(np.__version__)
# Out:
# '1.21.5'

# %%
(pd.__version__)
# Out:
# '1.4.4'

# %%
(sns.__version__)
# Out:
# '0.11.2'

# %% [markdown]
# ### Q1. Find the number of episodes?

# %%
print("number of episodes",(df['episode_number'].nunique()))
# Out:
# number of episodes 35

# %% [markdown]
# ### Q2. Max, min , mean of asked amount,asked equity, asked valuation?

# %%
df.groupby(['ask_equity','pitcher_ask_amount','ask_valuation']).agg({'ask_equity':["mean","min","max"],
                                                                 'pitcher_ask_amount':["mean","min","max"],
                                                                  'ask_valuation':["mean","min","max"]})
# Out:
#                                             ask_equity                \
#                                                   mean    min    max
# ask_equity pitcher_ask_amount ask_valuation
# 0.25       100.0              40000.00            0.25   0.25   0.25
# 1.00       35.0               3500.00             1.00   1.00   1.00
#            50.0               5000.00             1.00   1.00   1.00
#            65.0               6500.00             1.00   1.00   1.00
#            70.0               7000.00             1.00   1.00   1.00
# ...                                                ...    ...    ...
# 10.00      80.0               800.00             10.00  10.00  10.00
# 15.00      40.0               266.67             15.00  15.00  15.00
#            75.0               500.00             15.00  15.00  15.00
# 20.00      10.0               50.00              20.00  20.00  20.00
# 25.00      30000.0            120000.00          25.00  25.00  25.00
#
# ...

# %% [markdown]
# ### Q3. Max & Min asked- equity,asked-valuation and asked amount episode-wise?

# %%
df.groupby(['episode_number','ask_equity','pitcher_ask_amount','ask_valuation']).agg({'ask_equity':["mean","min","max"],
                                                                 'pitcher_ask_amount':["mean","min","max"],
                                                                  'ask_valuation':["mean","min","max"]})
# Out:
#                                                            ask_equity        \
#                                                                  mean   min
# episode_number ask_equity pitcher_ask_amount ask_valuation
# 1              5.0        50.0               1000.00              5.0   5.0
#                10.0       25.0               250.00              10.0  10.0
#                15.0       40.0               266.67              15.0  15.0
# 2              1.0        70.0               7000.00              1.0   1.0
#                5.0        50.0               1000.00              5.0   5.0
# ...                                                               ...   ...
# 34             7.5        30.0               400.00               7.5   7.5
#                10.0       40.0               400.00              10.0  10.0
# 35             2.5        100.0              4000.00              2.5   2.5
#                4.0        50.0               1250.00              4.0   4.0
# ...

# %% [markdown]
# ### Q4. Brand names in which 2 ,3 or 4 sharks are invested?

# %%
Brand_names=df.loc[(df['total_sharks_invested']>1) & (df['total_sharks_invested']<5),['brand_name','total_sharks_invested']]
Brand_names.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q5. Episode wise minimum and maximum of sharks invested?

# %%
min_maxsharks=df.groupby('episode_number')['total_sharks_invested'].agg(['min', 'max']).plot.bar()
min_maxsharks
# Out:
# <AxesSubplot:xlabel='episode_number'>

# %% [markdown]
# ### Q6. Minimum and Maximum sharks invested in each brand?

# %%
data=df[["brand_name","total_sharks_invested"]].sort_values(by='total_sharks_invested',ascending=False)
data
# Out:
#                 brand_name  total_sharks_invested
# 49   Find Your Kicks India                      5
# 79     Sunfox Technologies                      5
# 15             Skippi Pops                      5
# 63                IN A CAN                      5
# 58                 WeSTOCK                      4
# ..                     ...                    ...
# 73          Guardian Gears                      0
# 74             Modern Myth                      0
# 77          Nuskha Kitchen                      0
# 80                  Alpino                      0
# 116           Elcare India                      0
#
# [117 rows x 2 columns]

# %% [markdown]
# ### Q7. Brand names who ask for 1 crore and got a deal?

# %%
df[(df["pitcher_ask_amount"]==100) & (df["deal"]==1)][["brand_name","pitcher_ask_amount","deal_amount"]].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_26870">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26870_level0_col0" class="col_heading level0 col0" >brand_name</th>
#       <th id="T_26870_level0_col1" class="col_heading level0 col1" >pitcher_ask_amount</th>
#       <th id="T_26870_level0_col2" class="col_heading level0 col2" >deal_amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26870_level0_row0" class="row_heading level0 row0" >12</th>
#       <td id="T_26870_row0_col0" class="data row0 col0" >Revamp Moto</td>
#       <td id="T_26870_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_26870_row0_col2" class="data row0 col2" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_26870_level0_row1" class="row_heading level0 row1" >39</th>
#       <td id="T_26870_row1_col0" class="data row1 col0" >The Renal Project</td>
# ...

# %%
df[(df["pitcher_ask_amount"]==100) & (df["deal"]==1)][["brand_name","pitcher_ask_amount","deal_amount"]].set_index("brand_name").plot.bar()
# Out:
# <AxesSubplot:xlabel='brand_name'>

# %% [markdown]
# ### Q8. Brand names where deal equity is between 0 to 50?

# %%
Deal_equity=df[(df["deal_equity"]>= 0)& (df["deal_equity"]<=50)][["brand_name","ask_equity","deal_equity"]].style
Deal_equity.background_gradient(cmap='gist_heat')
# Out:
# <style type="text/css">
# #T_b9a00_row0_col1, #T_b9a00_row4_col1, #T_b9a00_row5_col1, #T_b9a00_row13_col1, #T_b9a00_row15_col1, #T_b9a00_row24_col1, #T_b9a00_row26_col1, #T_b9a00_row27_col1, #T_b9a00_row28_col1, #T_b9a00_row31_col1, #T_b9a00_row35_col1, #T_b9a00_row36_col1, #T_b9a00_row41_col1, #T_b9a00_row44_col1, #T_b9a00_row51_col1, #T_b9a00_row57_col1, #T_b9a00_row58_col1, #T_b9a00_row62_col1, #T_b9a00_row65_col1, #T_b9a00_row67_col1, #T_b9a00_row68_col1, #T_b9a00_row70_col1, #T_b9a00_row72_col1, #T_b9a00_row73_col1, #T_b9a00_row85_col1, #T_b9a00_row88_col1, #T_b9a00_row89_col1, #T_b9a00_row90_col1, #T_b9a00_row106_col1 {
#   background-color: #4a0000;
#   color: #f1f1f1;
# }
# #T_b9a00_row0_col2 {
#   background-color: #7a0000;
#   color: #f1f1f1;
# }
# #T_b9a00_row1_col1, #T_b9a00_row93_col1 {
#   background-color: #e43100;
#   color: #f1f1f1;
# }
# #T_b9a00_row1_col2, #T_b9a00_row30_col1, #T_b9a00_row80_col2 {
#   background-color: #ffffff;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Q9. Find the number of brands participated in each episode?

# %%
num_per_episode = df.groupby('episode_number')['brand_name'].count()
num_per_episode
# Out:
# episode_number
# 1     3
# 2     3
# 3     3
# 4     3
# 5     3
# 6     3
# 7     3
# 8     3
# 9     3
# 10    3
# 11    3
# 12    3
# 13    3
# 14    3
# 15    3
# 16    4
# 17    4
# 18    4
# 19    4
# 20    3
# 21    3
# 22    4
# 23    4
# 24    3
# 25    3
# 26    3
# 27    4
# 28    3
# 29    3
# 30    4
# 31    4
# 32    4
# 33    4
# 34    4
# 35    3
# Name: brand_name, dtype: int64

# %% [markdown]
# ### Q10. How many sharks participated in this show and What were their names?

# %%
age_cols = [col for col in df.columns if 'present' in col]
df3 = pd.DataFrame(age_cols)
df3
# Out:
#                  0
# 0  ashneer_present
# 1   anupam_present
# 2     aman_present
# 3   namita_present
# 4  vineeta_present
# 5   peyush_present
# 6   ghazal_present

# %% [markdown]
# ### Q11. Find appearance of each sharks?

# %%
sm=df[["ashneer_present","anupam_present","aman_present","namita_present","vineeta_present","peyush_present","ghazal_present"]]
present=sm.sum()
present.plot.bar(color=['red','black','blue','pink','green','cyan','purple'])
plt.xlabel("Sharks")
plt.ylabel("Present")
plt.title("Appearance of each sharks")
# Out:
# Text(0.5, 1.0, 'Appearance of each sharks')

# %% [markdown]
# ### Q12. How many entrepreneurs were present?

# %%
num_entrepreneurs =df['pitch_number'].nunique()
print("Number of entrepreneurs present:", num_entrepreneurs)
# Out:
# Number of entrepreneurs present: 117

# %% [markdown]
# ### Q13. How many times each shark invested the deal?

# %%
data1=df[['ashneer_deal','aman_deal','peyush_deal','anupam_deal','vineeta_deal','ghazal_deal','namita_deal']]
data1.sum().plot.bar()
# Out:
# <AxesSubplot:>

# %%
deal_shark = { 'Ashneer': (df['ashneer_deal'] == 1).sum(),
                'Aman': (df['aman_deal'] == 1).sum(),
                'Peyush': (df['peyush_deal'] == 1).sum(),
                'Anupam': (df['anupam_deal'] == 1).sum(),
                'Vineeta': (df['vineeta_deal'] == 1).sum(),
                'Ghazal': (df['ghazal_deal'] == 1).sum(),
                'Namita': (df['namita_deal'] == 1).sum()
               }

# %%
type(deal_shark)
# Out:
# dict

# %%
deal_shark2 = pd.Series(deal_shark)
deal_shark2
# Out:
# Ashneer    21
# Aman       28
# Peyush     27
# Anupam     24
# Vineeta    15
# Ghazal      7
# Namita     22
# dtype: int64

# %% [markdown]
# ### Q14. Find the equity percent that each sharks gets?

# %%
ab=df[['brand_name','equity_per_shark']][df['vineeta_deal']>0].sort_values(by='equity_per_shark',ascending=False)
ab1=ab.reset_index(drop=True)
ab1
# Out:
#                   brand_name  equity_per_shark
# 0              Booz scooters         25.000000
# 1        Heart up my Sleeves         15.000000
# 2                       NOCD         15.000000
# 3                      Cosiq         12.500000
# 4            The Quirky Nari         12.000000
# 5   Gold Safe Solutions Ind.         10.000000
# 6              Jain Shikanji          7.500000
# 7                Wakao Foods          7.000000
# 8        BluePine Industries          5.333333
# 9                 Get a Whey          5.000000
# 10                  Humpy A2          5.000000
# 11        Nomad Food Project          5.000000
# 12               Skippi Pops          3.000000
# 13              Kabaddi Adda          3.000000
# 14       Sunfox Technologies          1.200000

# %%
ab=df[['brand_name','equity_per_shark']][df['ghazal_deal']>0].sort_values(by='equity_per_shark',ascending=False)
ab1=ab.reset_index(drop=True)
ab1
# Out:
#                  brand_name  equity_per_shark
# 0              The Sass Bar              17.5
# 1  Gold Safe Solutions Ind.              10.0
# 2               Wakao Foods               7.0
# 3                  Humpy A2               5.0
# 4        Nomad Food Project               5.0
# 5       Sunfox Technologies               1.2
# 6        Watt Technovations               1.0

# %%
ab=df[['brand_name','equity_per_shark']][df['aman_deal']>0].sort_values(by='equity_per_shark',ascending=False)
ab1=ab.reset_index(drop=True)
ab1
# Out:
#                brand_name  equity_per_shark
# 0        Hammer Lifestyle         40.000000
# 1            Namhya Foods         10.000000
# 2                   Farda         10.000000
# 3                    LOKA          8.000000
# 4           Jain Shikanji          7.500000
# 5            Beyond Water          7.500000
# 6                Meatyour          6.666667
# 7                 Nuutjob          6.666667
# 8               Let's Try          6.000000
# 9               Peeschute          6.000000
# 10    BluePine Industries          5.333333
# 11                  Ariro          5.000000
# 12  Find Your Kicks India          5.000000
# 13             Get a Whey          5.000000
# 14                 Bummer          3.750000
# 15                  Altor          3.500000
# 16      The Renal Project          3.000000
# 17            Skippi Pops          3.000000
# 18               AyuRythm          2.680000
# 19        The Yarn Bazaar          2.500000
# ...

# %%
ab=df[['brand_name','equity_per_shark']][df['anupam_deal']>0].sort_values(by='equity_per_shark',ascending=False)
ab1=ab.reset_index(drop=True)
ab1
# Out:
#                         brand_name  equity_per_shark
# 0                     The Sass Bar         17.500000
# 1   Vivalyf Innovations- Easy Life         16.650000
# 2              Heart up my Sleeves         15.000000
# 3                        PawsIndia         15.000000
# 4         ARRCOAT Surface Textures         15.000000
# 5                            Cosiq         12.500000
# 6                  The Quirky Nari         12.000000
# 7                        Caragreen         10.000000
# 8                             LOKA          8.000000
# 9                    Jain Shikanji          7.500000
# 10                        Meatyour          6.666667
# 11                       Let's Try          6.000000
# 12           Find Your Kicks India          5.000000
# 13                      Tweek Labs          3.333333
# 14                     Skippi Pops          3.000000
# 15                 The Yarn Bazaar          2.500000
# 16                        IN A CAN          2.000000
# ...

# %%
ab=df[['brand_name','equity_per_shark']][df['peyush_deal']>0].sort_values(by='equity_per_shark',ascending=False)
ab1=ab.reset_index(drop=True)
ab1
# Out:
#                         brand_name  equity_per_shark
# 0                    Sid07 Designs         75.000000
# 1                  Isak Fragrances         50.000000
# 2                      KG Agrotech         40.000000
# 3                              PNT         25.000000
# 4                       RoadBounce         20.000000
# 5   Vivalyf Innovations- Easy Life         16.650000
# 6         Gold Safe Solutions Ind.         10.000000
# 7                        Caragreen         10.000000
# 8                             LOKA          8.000000
# 9                          Nuutjob          6.666667
# 10                        Meatyour          6.666667
# 11                           Ariro          5.000000
# 12                        Humpy A2          5.000000
# 13                          Proxgy          5.000000
# 14                   Aas Vidyalaya          5.000000
# 15           Find Your Kicks India          5.000000
# 16              Insurance Samadhan          4.000000
# ...

# %%
ab=df[['brand_name','equity_per_shark']][df['namita_deal']>0].sort_values(by='equity_per_shark',ascending=False)
ab1=ab.reset_index(drop=True)
ab1
# Out:
#                brand_name  equity_per_shark
# 0           Colour Me Mad         25.000000
# 1            Menstrupedia         20.000000
# 2          Auli Lifestyle         15.000000
# 3                   Farda         10.000000
# 4            Beyond Water          7.500000
# 5             Wakao Foods          7.000000
# 6                 Nuutjob          6.666667
# 7   Find Your Kicks India          5.000000
# 8           Aas Vidyalaya          5.000000
# 9      Nomad Food Project          5.000000
# 10                 Bummer          3.750000
# 11                  Altor          3.500000
# 12            Skippi Pops          3.000000
# 13      The Renal Project          3.000000
# 14            Rare Planet          3.000000
# 15           Kabaddi Adda          3.000000
# 16                WeSTOCK          2.500000
# 17               IN A CAN          2.000000
# 18                Cocofit          1.666667
# 19    Sunfox Technologies          1.200000
# ...

# %% [markdown]
# ### Q15. Find the total number of amount invested in this show?

# %%
data=df[df["deal"]==1]
data['deal_amount'].sum()
# Out:
# 3642.00106
